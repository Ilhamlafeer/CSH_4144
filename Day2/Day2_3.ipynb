# %%
import numpy as np
import pandas as pd

df1=pd.DataFrame(np.random.rand(10,4),columns=('col1','col2','col3','col4'))

# %%
print(df1)
# Out:
#        col1      col2      col3      col4
# 0  0.264925  0.055221  0.043599  0.883245
# 1  0.456832  0.569758  0.955461  0.211308
# 2  0.462593  0.522607  0.726235  0.074198
# 3  0.549119  0.839072  0.693356  0.701962
# 4  0.133720  0.386080  0.582576  0.385021
# 5  0.583668  0.569204  0.228659  0.514893
# 6  0.398769  0.381790  0.697193  0.631250
# 7  0.657662  0.691546  0.744044  0.388716
# 8  0.288970  0.762808  0.579186  0.627774
# 9  0.962248  0.565093  0.305975  0.870011

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot(subplots=True, figsize=(8,8))
#figsize(width,height) where dimensions should be given in inches
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df1.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='pie', y='col3')
# Out:
# <AxesSubplot:ylabel='col3'>

# %%
df1.hist()
# Out:
# array([[<AxesSubplot:title={'center':'col1'}>,
#         <AxesSubplot:title={'center':'col2'}>],
#        [<AxesSubplot:title={'center':'col3'}>,
#         <AxesSubplot:title={'center':'col4'}>]], dtype=object)

# %%
df1.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='scatter', x=2, y='col2')
# Out:
# <AxesSubplot:xlabel='col3', ylabel='col2'>

# %%
df1.plot(kind='area')
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1.plot(kind='hexbin' , x='col2',y='col1',gridsize=30)
# Out:
# <AxesSubplot:xlabel='col2', ylabel='col1'>

# %%
df1.plot(kind='hexbin' , x='col2',y='col1',gridsize=10)
# Out:
# <AxesSubplot:xlabel='col2', ylabel='col1'>
